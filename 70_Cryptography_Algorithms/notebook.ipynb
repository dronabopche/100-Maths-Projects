# %% [markdown]
# # Cryptography Algorithms

# %% [markdown]
# ## Imports & Configuration

# %%
import numpy as np
import matplotlib.pyplot as plt
plt.style.use('seaborn-v0_8-darkgrid')

print('Project: Magic Square Generator')

# %% [markdown]
# ## Core Implementation
