# %% [markdown]
# # Bayes Theorem Calculator
#
# Compute posterior probabilities using Bayes' theorem with medical testing and spam filtering examples.

# %% [markdown]
# ## Imports & Configuration

# %%
import numpy as np
import matplotlib.pyplot as plt
plt.style.use('seaborn-v0_8-darkgrid')
print('Project: Bayes Theorem Calculator')
